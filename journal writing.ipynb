My best friend is… (explain…)
One item that I would really like to own is.. (explain why…)
My favorite teacher is… (explain…)
A person that I think is brave is… (explain…)
The most luck I ever had was when… (explain…)
The skill that I spent a lot of time on, and finally got good at was… (explain…) 
If I found a spaceship, this is what I would do… (explain…) 
If I had ten thousand dollars to spend in one day, this is what I would do… (describe…) 
The three things that make my feel the happiest are… (explain…)
Something that I would like to change about my school is… (explain…)
Something that I would like to change about myself is… (explain…)
One thing that I really like about my neighbourhood is… (explain…)
One thing that I really like about my family is… (explain…)
I was disappointed when… (explain…) 
I was very proud when… (explain…)
I felt sad when… (explain…)
I was super excited when… (explain…) 
Something that I have always wanted to do is… (explain…) 
One day, when I’m older… (describe…) 
When I’m bored… (explain…) 
When I feel most alive is when… (explain…)
The best holiday for me is… (explain…)
The meal that is the best at home is… (explain…)
Three surprising things about me are… (explain…) 
One day in the far away future that I really look forward to is… (explain…)
Generosity is important because… (explain…)
When I get stressed, something that helps is… (explain…)
Something that makes me unique  and original is … (explain…)
How have you changed from the person you were three years ago… (explain…)
The happiest moment of my life was when… (describe…)
The people in my life that mean a lot are … (who are they, and why…) 
Three ways that a person can make the world better, are… (explain…) 
I would want my friends to know me as a person who… (explain…)
The place that makes me feel at peace is… (explain…)
The activity that makes me feel at peace is… (explain…)
The most beautiful thing in the world is… (explain…)'''.strip().split('\n')


def worksheets(num, a):
    
    prs = Presentation('/Users/samuelaltarac/Desktop/python programs/Generator/gen/test.pptx')

    bullet_slide_layout = prs.slide_layouts[1]

    slide = prs.slides.add_slide(bullet_slide_layout)
    shapes = slide.shapes

    title_shape = shapes.title
    body_shape = shapes.placeholders[1]

#     title_shape.text = "Writer's Workshop; Cliches Quick Write"


    left = Inches(1.3)
    top = Inches(1)

    pic = slide.shapes.add_picture('/Users/samuelaltarac/Desktop/python programs/Generator/gen/imgs/journalcover.jpg', left, top, height=Inches(8))

    
    for j in range(num):
        
        blank_slide_layout = prs.slide_layouts[6]
        slide = prs.slides.add_slide(blank_slide_layout)
#         width = height = Inches(3)
#         txBox = slide.shapes.add_textbox(Inches(0.5), Inches(0.5), Inches(3), height)
#         tf = txBox.text_frame

#         tf.text = "Name:________________"
        
        img_path = '/Users/samuelaltarac/Desktop/python programs/Generator/gen/imgs/journal.jpg'
      
        width = Inches(7.48)
        height = Inches(10.04)
        pic = slide.shapes.add_picture(img_path, Inches(0), Inches(0), width, height)

#         width = Inches(5)
#         height = Inches(1)
#         txBox = slide.shapes.add_textbox(Inches(2), Inches(3), width, height)
#         tf = txBox.text_frame
#         tf.word_wrap = True

#         tf.text = "Write a 100 word descriptive narrative \n for the given topic and which \n incorporates the 3 given choices of cliches"
        
        width = Inches(5)
        height = Inches(1)
        txBox = slide.shapes.add_textbox(Inches(1.24), Inches(4.5), width, height)
        tf = txBox.text_frame
        tf.word_wrap = True

        tf.text = f"1. {choice(topics)} \n 2. {choice(topics)} \n 3. {choice(topics)} \n"
        
#         width = Inches(4.5)
#         height = Inches(2)
#         txBox = slide.shapes.add_textbox(Inches(2), Inches(6.77), width, height)
#         tf = txBox.text_frame
#         tf.word_wrap = True

#         tf.text = f"1. {choice(cliches)} \n 2. {choice(cliches)} \n 3. {choice(cliches)}"

        for g in range(2):
        
            blank_slide_layout = prs.slide_layouts[6]
            slide = prs.slides.add_slide(blank_slide_layout)
            img_path = '/Users/samuelaltarac/Desktop/python programs/Generator/gen/imgs/linedpaper.png'
            width = Inches(7.48)
            height = Inches(10.04)
            pic = slide.shapes.add_picture(img_path, Inches(0), Inches(0), width, height)


    prs.save(f'/Users/samuelaltarac/Desktop/python programs/Generator/gen/journal{a}.pptx')

# %%
for i in range(3):
    worksheets(100, i)
